# %%
#accessing elements in a list
marks=[80,90,75,85]

print(marks[0])
print(marks[1])
print(marks[2])
print(marks[3])
# Out:
# 80
# 90
# 75
# 85

# %%
#change elements in a list
marks=[80,90,75,65,45,85]

marks[1]=95
marks[3]=35
marks[5]=25

print(marks)
# Out:
# [80, 95, 75, 35, 45, 25]

# %%
#add elements to a list  
marks=[65,75,85]

marks.append(70)

print(marks)
# Out:
# [65, 75, 85, 70]

# %%
#remove elements from list 
marks=[80,90,95]

remove=90

print(marks)
# Out:
# [80, 90, 95]

# %%
numbers=[10,20,30]

numbers.insert(1,15)

print(numbers)
# Out:
# [10, 15, 20, 30]

# %%
numbers=[15,25,35]

numbers.insert(2,45)

print(numbers)
# Out:
# [15, 25, 45, 35]

# %%
#bitwise operators
a=15
b=3

print(a>>b)
# Out:
# 1

# %%
#bitwise operators
a=7
b=2

print(a>>b)
# Out:
# 1

# %%
#bitwise operators
a=13
b=1

print(a>>b)
# Out:
# 6

# %%
#bitwise operators
a=9
b=2

print(a>>b)
# Out:
# 2

# %%
#bitwise operators 
a=15
b=6 
print(a<<b)
# Out:
# 960

# %%
#bitwise operators
a=12
b=4

print(a<<b)
# Out:
# 192

# %%
#bitwise operators
a=11
b=5 

print(a<<b)
# Out:
# 352

# %%
#bitwise operators
a=14
b=7

print(a<<b)
# Out:
# 1792

# %%
a=[1,2,3]
b=[4,5,6]

a.extend(b)

print(a)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
numbers=[20,20,30,20]

numbers.remove(20)

print(numbers)
# Out:
# [20, 30, 20]

# %%
numbers=[5,6,7]

numbers.clear()

print(numbers)
# Out:
# []

# %%
numbers=[10,20,30,40]

print(numbers.index(30))
# Out:
# 2

# %%
numbers=[10,20,20,30,20,]

print(numbers.count(20))
# Out:
# 3

# %%
numbers=[90,45,69,29,90,69,24,45,29,69]

print(numbers.count(45))

print(numbers.count(69))

print(numbers.count(90))

print(numbers.count(29))
# Out:
# 2
# 3
# 2
# 2

# %%
numbers=[40,10,30,20]

numbers.sort()

print(numbers)

numbers.sort(reverse=True)

print(numbers)
# Out:
# [10, 20, 30, 40]
# [40, 30, 20, 10]

# %%
numbers=[10,20,30,40]

numbers.sort(reverse=True)

print(numbers)
# Out:
# [40, 30, 20, 10]

# %%
a=[1,2,3]

b=a.copy()

print(b)
# Out:
# [1, 2, 3]

# %%
numbers=[10,20,30,40,50]

print(numbers[1:4])
print(numbers[:3])
print(numbers[2:])
print(numbers[::-1])
# Out:
# [20, 30, 40]
# [10, 20, 30]
# [30, 40, 50]
# [50, 40, 30, 20, 10]

# %%
numbers=[-1,-2,-3,-4,-5]

print(numbers[-1::])
print(numbers[::-5])
print(numbers[-5::])
# Out:
# [-5]
# [-5]
# [-1, -2, -3, -4, -5]
